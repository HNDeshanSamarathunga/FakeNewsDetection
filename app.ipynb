# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['class'] = 0
true['class'] = 1

# %%
data = pd.concat([fake,true],axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 8961    Conservatives Invent Conspiracy Theory To Bla...
# 4858    Sarah Palin Faceplants, Immediately Starts Sp...
# 10778  Sanders, Trump give union hope in fight for Ca...
# 8773    President Obama Hammers Republicans: They’re ...
# 8696    Carlos Santana Praises President Obama, Says ...
# 2026   Trump calls Egypt's Sisi, says keen to overcom...
# 20607  Irma to stress-test Florida insurers, reinsure...
# 7519    Legendary Investigative Journalist Carl Berns...
# 546    JPMorgan's Dimon says Trump likely to be a one...
# 14827  Lebanon's Hariri shackled by bigger outside fo...
#
#                                                     text       subject  \
# 8961   Even the crankiest section of America s right ...          News
# 4858   Half-term Governor of Alaska and professional ...          News
# 10778  INDIANAPOLIS (Reuters) - Duane Oreskowic was s...  politicsNews
# 8773   A day after he schooled Republicans during his...          News
# 8696   In an open letter to President Obama, legendar...          News
# 2026   CAIRO (Reuters) - U.S. President Donald Trump ...  politicsNews
# 20607  (Reuters) - Florida s insurance and reinsuranc...     worldnews
# 7519   Veteran investigative reporter Carl Bernstein ...          News
# 546    CHICAGO/NEW YORK (Reuters) - Jamie Dimon, chie...  politicsNews
# 14827   BEIRUT (Reuters) - Nothing so encapsulated th...     worldnews
#
#                      date  class
# 8961      January 5, 2016      0
# 4858      August 29, 2016      0
# 10778  February 19, 2016       1
# 8773     January 13, 2016      0
# 8696     January 17, 2016      0
# 2026     August 25, 2017       1
# 20607  September 8, 2017       1
# 7519       March 13, 2016      0
# 546    November 22, 2017       1
# 14827  November 13, 2017       1
